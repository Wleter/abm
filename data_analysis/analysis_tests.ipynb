# %% [markdown]
# https://doi.org/10.48550/arXiv.1007.0886

# %%
import matplotlib.pyplot as plt
import numpy as np
import utility

# %% [markdown]
# # Hyperfine

# %%
data = np.loadtxt('../data/hifi_single.dat', delimiter='\t', skiprows=1)

fig, ax = utility.plot()
ax.set_xlabel("magnetic field [G]")
ax.set_ylabel("energy [a.u.]")

ax.plot(data[:, 0], data[:, 1::])

# %%
data = np.loadtxt('../data/hifi_double.dat', delimiter='\t', skiprows=1)

fig, ax = utility.plot()
ax.set_xlabel("magnetic field [G]")
ax.set_ylabel("energy [a.u.]")

ax.plot(data[:, 0], data[:, 1::])

# %%
data = np.loadtxt('../data/simple_abm.dat', delimiter='\t', skiprows=1)

fig, ax = utility.plot()
ax.set_xlabel("magnetic field [G]")
ax.set_ylabel("energy [a.u.]")

ax.plot(data[:, 0], data[:, 1::])
